# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from src.limpieza.eliminar import eliminar_nulos
from src.utils.carga import cargar_csv

df=cargar_csv("../data/original/Student Depression Dataset.csv")


df = eliminar_nulos(df)
# Out:
# Tiene: id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64 nulos

# %%
#Convertir variables categoricas
df["Gender"] = df["Gender"].astype("category")
df["City"] = df["City"].astype("category")

# %%
#Codificacion
df["Family History of Mental Illness"] = df["Family History of Mental Illness"].map({"Yes":1, "No":0})

# %%
#Guardado
df.to_csv("../data/procesado/dataset_limpio.csv", index=False)
